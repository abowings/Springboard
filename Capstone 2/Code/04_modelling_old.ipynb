# %% [markdown]
# # 4 Pre-Processing and Training Data<a id='4_Pre-Processing_and_Training_Data'></a>

# %% [markdown]
# ## 4.1 Contents<a id='4.1_Contents'></a>
# * [4 Pre-Processing and Training Data](#4_Pre-Processing_and_Training_Data)
#   * [4.1 Contents](#4.1_Contents)
#   * [4.2 Imports](#4.2_Imports)
#   * [4.3 Load Data](#4.3_Load_Data)
#   * [4.4 Extract Spotify Data](#4.4_Extract_Spotify_Data)
#   * [4.5 Train/Test Split](#4.5_Train/Test_Split)
#   * [4.7 Initial Not-Even-A-Model](#4.7_Initial_Not-Even-A-Model)
#     * [4.7.1 Metrics](#4.7.1_Metrics)
#       * [4.7.1.1 R-squared, or coefficient of determination](#4.7.1.1_R-squared,_or_coefficient_of_determination)
#       * [4.7.1.2 Mean Absolute Error](#4.7.1.2_Mean_Absolute_Error)
#       * [4.7.1.3 Mean Squared Error](#4.7.1.3_Mean_Squared_Error)
#     * [4.7.2 sklearn metrics](#4.7.2_sklearn_metrics)
#         * [4.7.2.0.1 R-squared](#4.7.2.0.1_R-squared)
#         * [4.7.2.0.2 Mean absolute error](#4.7.2.0.2_Mean_absolute_error)
#         * [4.7.2.0.3 Mean squared error](#4.7.2.0.3_Mean_squared_error)
#     * [4.7.3 Note On Calculating Metrics](#4.7.3_Note_On_Calculating_Metrics)
#   * [4.8 Initial Models](#4.8_Initial_Models)
#     * [4.8.1 Imputing missing feature (predictor) values](#4.8.1_Imputing_missing_feature_(predictor)_values)
#       * [4.8.1.1 Impute missing values with median](#4.8.1.1_Impute_missing_values_with_median)
#         * [4.8.1.1.1 Learn the values to impute from the train set](#4.8.1.1.1_Learn_the_values_to_impute_from_the_train_set)
#         * [4.8.1.1.2 Apply the imputation to both train and test splits](#4.8.1.1.2_Apply_the_imputation_to_both_train_and_test_splits)
#         * [4.8.1.1.3 Scale the data](#4.8.1.1.3_Scale_the_data)
#         * [4.8.1.1.4 Train the model on the train split](#4.8.1.1.4_Train_the_model_on_the_train_split)
#         * [4.8.1.1.5 Make predictions using the model on both train and test splits](#4.8.1.1.5_Make_predictions_using_the_model_on_both_train_and_test_splits)
#         * [4.8.1.1.6 Assess model performance](#4.8.1.1.6_Assess_model_performance)
#       * [4.8.1.2 Impute missing values with the mean](#4.8.1.2_Impute_missing_values_with_the_mean)
#         * [4.8.1.2.1 Learn the values to impute from the train set](#4.8.1.2.1_Learn_the_values_to_impute_from_the_train_set)
#         * [4.8.1.2.2 Apply the imputation to both train and test splits](#4.8.1.2.2_Apply_the_imputation_to_both_train_and_test_splits)
#         * [4.8.1.2.3 Scale the data](#4.8.1.2.3_Scale_the_data)
#         * [4.8.1.2.4 Train the model on the train split](#4.8.1.2.4_Train_the_model_on_the_train_split)
#         * [4.8.1.2.5 Make predictions using the model on both train and test splits](#4.8.1.2.5_Make_predictions_using_the_model_on_both_train_and_test_splits)
#         * [4.8.1.2.6 Assess model performance](#4.8.1.2.6_Assess_model_performance)
#     * [4.8.2 Pipelines](#4.8.2_Pipelines)
#       * [4.8.2.1 Define the pipeline](#4.8.2.1_Define_the_pipeline)
#       * [4.8.2.2 Fit the pipeline](#4.8.2.2_Fit_the_pipeline)
#       * [4.8.2.3 Make predictions on the train and test sets](#4.8.2.3_Make_predictions_on_the_train_and_test_sets)
#       * [4.8.2.4 Assess performance](#4.8.2.4_Assess_performance)
#   * [4.9 Refining The Linear Model](#4.9_Refining_The_Linear_Model)
#     * [4.9.1 Define the pipeline](#4.9.1_Define_the_pipeline)
#     * [4.9.2 Fit the pipeline](#4.9.2_Fit_the_pipeline)
#     * [4.9.3 Assess performance on the train and test set](#4.9.3_Assess_performance_on_the_train_and_test_set)
#     * [4.9.4 Define a new pipeline to select a different number of features](#4.9.4_Define_a_new_pipeline_to_select_a_different_number_of_features)
#     * [4.9.5 Fit the pipeline](#4.9.5_Fit_the_pipeline)
#     * [4.9.6 Assess performance on train and test data](#4.9.6_Assess_performance_on_train_and_test_data)
#     * [4.9.7 Assessing performance using cross-validation](#4.9.7_Assessing_performance_using_cross-validation)
#     * [4.9.8 Hyperparameter search using GridSearchCV](#4.9.8_Hyperparameter_search_using_GridSearchCV)
#   * [4.10 Random Forest Model](#4.10_Random_Forest_Model)
#     * [4.10.1 Define the pipeline](#4.10.1_Define_the_pipeline)
#     * [4.10.2 Fit and assess performance using cross-validation](#4.10.2_Fit_and_assess_performance_using_cross-validation)
#     * [4.10.3 Hyperparameter search using GridSearchCV](#4.10.3_Hyperparameter_search_using_GridSearchCV)
#   * [4.11 Final Model Selection](#4.11_Final_Model_Selection)
#     * [4.11.1 Linear regression model performance](#4.11.1_Linear_regression_model_performance)
#     * [4.11.2 Random forest regression model performance](#4.11.2_Random_forest_regression_model_performance)
#     * [4.11.3 Conclusion](#4.11.3_Conclusion)
#   * [4.12 Data quantity assessment](#4.12_Data_quantity_assessment)
#   * [4.13 Save best model object from pipeline](#4.13_Save_best_model_object_from_pipeline)
#   * [4.14 Summary](#4.14_Summary)

# %% [markdown]
# ## 4.2 Imports<a id='4.2_Imports'></a>

# %%
import pandas as pd
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import __version__ as sklearn_version
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, learning_curve
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_regression
import datetime

# %% [markdown]
# ## 4.3 Load Data<a id='4.3_Load_Data'></a>

# %%
spotify_data = pd.read_csv('../data/genre_music.csv')
spotify_data.head()
# Out:
#                    track            artist  danceability  energy  key  \
# 0  Jealous Kind Of Fella     Garland Green         0.417   0.620    3
# 1          Initials B.B.  Serge Gainsbourg         0.498   0.505    3
# 2           Melody Twist       Lord Melody         0.657   0.649    5
# 3          Mi Bomba Sonó        Celia Cruz         0.590   0.545    7
# 4            Uravu Solla       P. Susheela         0.515   0.765   11
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -7.727     1       0.0403         0.490          0.000000    0.0779
# 1   -12.475     1       0.0337         0.018          0.107000    0.1760
# 2   -13.392     1       0.0380         0.846          0.000004    0.1190
# 3   -12.058     0       0.1040         0.706          0.024600    0.0610
# 4    -3.515     0       0.1240         0.857          0.000872    0.2130
#
#    valence    tempo  duration_s  time_signature  chorus_hit  sections  \
# 0    0.845  185.655     173.533               3    32.94975         9
# 1    0.797  101.801     213.613               4    48.82510        10
# 2    0.908  115.940     223.960               4    37.22663        12
# 3    0.967  105.592     157.907               4    24.75484         8
# 4    0.906  114.617     245.600               4    21.79874        14
#
#    popularity decade genre
# 0           1    60s   edm
# 1           0    60s   pop
# 2           0    60s   pop
# 3           0    60s   pop
# 4           0    60s   r&b

# %%
spotify_data.shape
# Out:
# (41099, 20)

# %% [markdown]
# ## 4.4 Extract Spotify Data<a id='4.4_Extract_Spotify_Data'></a>

# %%
#how is this different from above?

# %% [markdown]
# ## 4.5 Train/Test Split<a id='4.5_Train/Test_Split'></a>

# %%
len(spotify_data) * .7, len(spotify_data) * .3
# Out:
# (28769.3, 12329.699999999999)

# %%
X_train, X_test, y_train, y_test = train_test_split(spotify_data.drop(columns='genre'), 
                                                    spotify_data.genre, test_size=0.3, 
                                                    random_state=47)

# %%
X_train.shape, X_test.shape
# Out:
# ((28769, 19), (12330, 19))

# %%
y_train.shape, y_test.shape
# Out:
# ((28769,), (12330,))

# %%
names_list = ['key','mode','duration_s','time_signature','chorus_hit','sections','track','artist','decade','popularity']
names_train = X_train[names_list]
names_test = X_test[names_list]
X_train.drop(columns=names_list, inplace=True)
X_test.drop(columns=names_list, inplace=True)
X_train.shape, X_test.shape
# Out:
# ((28769, 9), (12330, 9))

# %%
X_train.dtypes
# Out:
# danceability        float64
# energy              float64
# loudness            float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# dtype: object

# %%
X_test.dtypes
# Out:
# danceability        float64
# energy              float64
# loudness            float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# dtype: object

# %% [markdown]
# ## 4.7 Initial Not-Even-A-Model<a id='4.7_Initial_Not-Even-A-Model'></a>

# %%
train_mean = y_train.mean()
train_mean
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\envs\sb\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1534         try:
# -> 1535             x = float(x)
#    1536         except ValueError:
#
# ValueError: could not convert string to float: 'rockpopr&bpoppopr&bpopr&brocklatinpoppoppoppopr&bpopr&bpoprockr&br&bpoprockr&brocklatinrocklatinr&br&bpoprockrockpoppoppoppopr&brockrappoppoppoppoppoppoprockr&brockpopr&bpoppoppopedmpoppopr&bpoppoppoppoppoprockpoppoplatinpopraprockpoppoprockr&brockr&blatinpopr&bpopr&bpopr&braplatinpoppoppoppoppopr&brockrockpopr&br&bpopr&br&brocklatinpoppoppopr&bpoprockpopedmr&br&brapr&br&bpoppoppopr&brappoplatinr&br&bpoprockpoplatinr&bpoppoppopr&brockpoprockr&bedmlatinpopr&br&br&bpoplatinr&bpopr&br&bpoppoppoppopr&bpoppopr&bpoprockrappoppoppoprappoprapr&blatinpopr&br&bpopr&br&bpoppopr&bpoppoppopr&brockrockedmpopedmr&bpopr&bpoppopr&brappoppoppopr&bpoppoppoppoppopedmrockpopr&bpoppoppopr&br&br&bpopr&br&bpoppoprockpoprockrockr&br&br&bpopr&br&bpopedmrockr&blatinpopr&brockpoppopr&br&bpopr&bpoppoprockr&brockpopr&brocklatinr&bedmrapr&brockrockr&brappoppopr&br&brapr&bpopr&bpopr&br&br&bpoppopr&br&bedmrockr&bpoppoppoppoprappoplatinpopr&bedmrappoppoprockr&brockpopr&bpoplatinr&bpoprappopraprockr&bpoprappoprockr&br&bpoprapedmr&bpoppopr&bedmpoprockr&bpoppoppoppopr&brockpopr&bpoppopr&blatinpoppoprockrockr&bpoppoprockrappoplatinpopr&br&bpoprockr&bpopraplatinr&bpoppoprockpoprockpoprockpoppoppopr&brockrapr&bpopr&braprockr&bpoprockr&br&bpoppoppoppoppoppopr&bpoprockrappopr&bpoplatinedmr&bpoprappopr&brockpoppoppopr&br&brockpoppoprockr&br&brockrockpoppopr&br&bpoprapr&brappoprockrapr&brockr&brockrockpoppopr&brockpopr&brappoppoppoprapr&brockpoppopedmrockpoppoppopr&brockpopr&bpoppoplatinpoppoppoprocklatinrappopr&bedmedmpoprockedmpoprockr&bpoppoppoppoprockr&bpopr&bedmr&bpoppoppopr&bpopr&blatinpoprockrapr&br&blatinr&bpoppoppopr&bpo
brockpoppopr&bpoprockpopraplatinpoprockr&blatinraplatinpopedmlatinr&br&braprockpopr&br&bpopr&bedmpoprocklatinpopr&bpoppopr&br&bpoppoppoppoppoppoplatinpopr&br&brockpoprockpopr&braprockedmpopedmpopr&bedmr&br&brockpoprockpoppoppoppoppoppoppoplatinpoprappoprockrockpoprappoppoppoprockrockr&br&blatinrockr&bedmr&bpoplatinpoppoplatinpoppoprockpopr&brockpopedmrockr&brockrockpoplatinr&brockr&brockpoppoprockrockr&br&brockr&br&br&bpoprocklatinraplatinpoppoplatinr&bpoppoppoppopr&br&bpoppoppoppoppoplatinr&br&bpoplatinrockpopr&bpoppoppoprockrockedmraprockrockedmrockr&bpopedmrockraprockedmpoppoprappoprockraplatinrockr&bpopr&brockr&br&bpoprockr&br&brappopr&br&bpopraprockpoprockpoppopr&bpoppoppopr&bpoplatinr&br&bpoprocklatinpoprockr&brocklatinlatinrappoppopr&bpoppoppoppoppoppopedmpoppopr&bpoppoprockpoplatinpoppoprockpopr&bpoppoppoppoppoprapr&br&brapr&bpopr&bpoppoprockrockpoppoprockpoppoplatinr&blatinrappopr&br&br&bpoprockpopr&br&blatinr&bpopr&br&bedmrappoprockr&br&bpoppoplatinpoprocklatinr&br&brapr&bpopr&bpoppoprappopr&blatinlatinpoppoppopr&bpoplatinpoprockr&br&bpoplatinrockpoprockrockpopedmpopr&br&br&bpoprockedmr&brockrappopr&bpoprockr&bpoplatinr&blatinpoppoppoppoprappoppoppoprappoppopr&brockpopr&br&br&bpoprockr&bpoplatinr&br&brockpopr&brockrockrockpopr&br&bpopr&br&brockrockpoplatinpoppoprappopr&brockr&blatinr&brockrockpopr&brockpopr&bpoppopr&bpoppoppoppoppoppoppoppoppoppopraprappoppoplatinpoprockrockrapr&bpopr&brockpoprockpoppoppopr&bpoppopr&bpoppoplatinr&bpopr&br&br&brockedmrockpoprockr&bpoppopraplatinr&br&bpoppoprockpoppoprockrockpopr&br&bedmr&brockrockpoppoprockpoppoppopr&bpopedmpoppopr&brockpoppoppopr&blatinpopr&bpopr&br&bpoppopr&bpoppoppopr&bpoprockrockr&br&bpoppoprapr&br&bpoplatinrappopr&bpoppoppopr&bpopraprockpoppopr&br&br&bpoprockpoppoppoppoppoprockpopr&bpoprapedmpoprockr&bpopr&br ...

# %%
dumb_reg = DummyRegressor(strategy='mean')
dumb_reg.fit(X_train, y_train)
dumb_reg.constant_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-b2ce411de505> in <module>
#       1 dumb_reg = DummyRegressor(strategy='mean')
# ----> 2 dumb_reg.fit(X_train, y_train)
#       3 dumb_reg.constant_
#
# ~\Anaconda3\envs\sb\lib\site-packages\sklearn\dummy.py in fit(self, X, y, sample_weight)
#     474                              % (self.strategy, allowed_strategies))
#     475
# --> 476         y = check_array(y, ensure_2d=False)
#     477         self.n_features_in_ = None  # No input validation is done for X
#     478         if len(y) == 0:
#
# ~\Anaconda3\envs\sb\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\Anaconda3\envs\sb\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# ~\Anaconda3\envs\sb\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ~\Anaconda3\envs\sb\lib\site-packages\pandas\core\series.py in __array__(self, dtype)
#     766               dtype='datetime64[ns]')
#     767         """
# --> 768         return np.asarray(self.array, dtype)
#     769
#     770     # ----------------------------------------------------------------------
#
# ~\Anaconda3\envs\sb\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ~\Anaconda3\envs\sb\lib\site-packages\pandas\core\arrays\numpy_.py in __array__(self, dtype)
#     201
#     202     def __array__(self, dtype=None) -> np.ndarray:
# --> 203         return np.asarray(self._ndarray, dtype=dtype)
#     204
#     205     _HANDLED_TYPES = (np.ndarray, numbers.Number)
#
# ~\Anaconda3\envs\sb\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'rock'
